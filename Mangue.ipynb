# %% [markdown]
# # Base interprofession Mangue

# %%
### importation des bibliothèque et importation de la base de donnée

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('Mangue.xlsx')
df.head()
# Out:
#                     start                     end  \
# 0 2026-03-05 11:42:00.421 2026-03-06 04:44:32.597
# 1 2026-03-05 16:54:09.798 2026-03-06 05:02:08.086
# 2 2026-03-09 11:36:33.665 2026-03-10 06:31:12.048
# 3 2026-03-09 14:47:27.763 2026-03-10 06:38:04.365
# 4 2026-03-16 13:09:25.646 2026-03-17 09:03:02.856
#
#    Info : Cher(e) participant(e),Dans le cadre de cette enquête, des données personnelles seront collectées. Ces données serviront uniquement à l'actualisation de la base de données des familles membres de l'interprofession. Votre participation est volontaire et vous pouvez arrêter l’entretien à tout moment, sans aucune conséquence négative. Elles ne seront pas transmises à des tiers non impliqués dans l'activité.   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
print(df.columns.tolist())
# Out:
# ['start', 'end', "Info : Cher(e) participant(e),Dans le cadre de cette enquête, des données personnelles seront collectées. Ces données serviront uniquement à l'actualisation de la base de données des familles membres de l'interprofession. Votre participation est volontaire et vous pouvez arrêter l’entretien à tout moment, sans aucune conséquence négative. Elles ne seront pas transmises à des tiers non impliqués dans l'activité. ", 'Consentez-vous à la collecte et à l’utilisation de vos données comme décrit ci-dessus ?', 'Date de l’enquête : ', 'Nom et prénoms de l’enquêteur : ', "Village de l'enquête : ", "Canton de l'enquête : ", "Région de l'enquête : ", "Type d'acteurs: ", 'Nom et prénoms du répondant ', 'Sexe du répondant  : ', 'Niveau instruction du répondant : ', 'Numéro de téléphone principal: ', 'Numéro de téléphone secondaire : ', 'Adresse électronique (mail): ', 'Poste occupé par le répondant  : ', 'Nom et prénoms du premier responsable', 'Sexe du premier responsable : ', 
# ...

# %%
df = df.drop( columns = ['start', 'end', "Info : Cher(e) participant(e),Dans le cadre de cette enquête, des données personnelles seront collectées. Ces données serviront uniquement à l'actualisation de la base de données des familles membres de l'interprofession. Votre participation est volontaire et vous pouvez arrêter l’entretien à tout moment, sans aucune conséquence négative. Elles ne seront pas transmises à des tiers non impliqués dans l'activité. ", 'Consentez-vous à la collecte et à l’utilisation de vos données comme décrit ci-dessus ?','_id', '_uuid', '_submission_time', '_validation_status', '_notes', '_status', '_submitted_by', '__version__', '_tags', 'meta/rootUuid',  "Nom de l'organisme certificateur : /CCPB", "Nom de l'organisme certificateur : /ECOCERT", "Nom de l'organisme certificateur : /SRS", "Nom de l'organisme certificateur : /ONECERT", "Nom de l'organisme certificateur : /CONTROL UNION", "Nom de l'organisme certificateur : /UNION", "Nom de l'organisme certificateur : /CERES", "Nom de l'organisme certificateur : /Global Gap", "Nom de l'organisme certificateur : /Bio SPG",'Variétés de mangue produites dans votre organisation : /Somnol', 'Variétés de mangue produites dans votre organisation : /Kents', 'Variétés de mangue produites dans votre organisation : /Eldonne', 'Variétés de mangue produites dans votre organisation : /Smith', 'Variétés de mangue produites dans votre organisation : /Mangue papaye ', 'Variétés de mangue produites dans votre organisation : /Gouverneur ', 'Variétés de mangue produites dans votre organisation : /Alfonse', 'Variétés de mangue produites dans votre organisation : /Cueillette', 'Variétés de mangue produites dans votre organisation : /Parlers ', 'Variétés de mangue produites dans votre organisation : /Camerounaise', 'Variétés de mangue produites dans votre organisation : /Rubis ', 'Variétés de mangue produites dans votre organisation : /Autres','Variétés de mangue produites dans votre organisation : /Somnol.1', 'Variétés de mangue produites dans votre organisation : /Kents.1', 'Variétés de mangue produites dans votre organisation : /Eldonne.1', 'Variétés de mangue produites dans votre organisation : /Smith.1', 'Variétés de mangue produites dans votre organisation : /Mangue papaye .1', 'Variétés de mangue produites dans votre organisation : /Gouverneur .1', 'Variétés de mangue produites dans votre organisation : /Alfonse.1', 'Variétés de mangue produites dans votre organisation : /Cueillette.1', 'Variétés de mangue produites dans votre organisation : /Parlers .1', 'Variétés de mangue produites dans votre organisation : /Camerounaise.1', 'Variétés de mangue produites dans votre organisation : /Rubis .1', 'Variétés de mangue produites dans votre organisation : /Autres.1','Produits dérivés à base de mangue : /Jus de mangue ', 'Produits dérivés à base de mangue : /Mangue séchée', 'Produits dérivés à base de mangue : /Poudre ', 'Produits dérivés à base de mangue : /Sirop de mangue ', 'Produits dérivés à base de mangue : /Autres ', 'Produits dérivés à base de mangue : /Confiture de mangue',"Nom de l'organisme certificateur : /CCPB", "Nom de l'organisme certificateur : /ECOCERT", "Nom de l'organisme certificateur : /SRS", "Nom de l'organisme certificateur : /ONECERT", "Nom de l'organisme certificateur : /CONTROL UNION", "Nom de l'organisme certificateur : /UNION", "Nom de l'organisme certificateur : /CERES", "Nom de l'organisme certificateur : /Global Gap", "Nom de l'organisme certificateur : /Bio SPG",'_index'])

# %%
print(df.columns.tolist())
# Out:
# ['Date de l’enquête : ', 'Nom et prénoms de l’enquêteur : ', "Village de l'enquête : ", "Canton de l'enquête : ", "Région de l'enquête : ", "Type d'acteurs: ", 'Nom et prénoms du répondant ', 'Sexe du répondant  : ', 'Niveau instruction du répondant : ', 'Numéro de téléphone principal: ', 'Numéro de téléphone secondaire : ', 'Adresse électronique (mail): ', 'Poste occupé par le répondant  : ', 'Nom et prénoms du premier responsable', 'Sexe du premier responsable : ', 'Adresse complète du premier responsable : ', 'Niveau instruction du premier responsable  : ', 'Numéro de téléphone principal du premier responsable :  ', 'Numéro de téléphone secondaire du premier responsable :  ', 'Adresse électronique (mail) du premier responsable : ', 'Statut sur le plan foncier du premier responsable : ', "Nom de l'organisation de base / structure ", 'Type d’organisation / structure', 'Autres ', 'Effectif des membres : ', 'Nombre de femmes : ', "Nombre d'hommes : ", "Date de création de l'organisati
# ...

# %%
renommer_colonnes = {
    # --- IDENTIFICATION DE L'ENQUÊTE ET DU RÉPONDANT ---
    'Date de l’enquête : ': 'date_enquete',
    'Nom et prénoms de l’enquêteur : ': 'nom_enqueteur',
    "Village de l'enquête : ": 'village',
    "Canton de l'enquête : ": 'canton',
    "Région de l'enquête : ": 'region',
    "Type d'acteurs: ": 'type_acteur',
    'Nom et prénoms du répondant ': 'nom_repondant',
    'Sexe du répondant  : ': 'sexe_repondant',
    'Niveau instruction du répondant : ': 'niveau_instruction_repondant',
    'Numéro de téléphone principal: ': 'tel_principal_repondant',
    'Numéro de téléphone secondaire : ': 'tel_secondaire_repondant',
    'Adresse électronique (mail): ': 'email_repondant',
    'Poste occupé par le répondant  : ': 'poste_repondant',

    # --- PROFIL 1 (ex: Pépiniéristes) ---
    'Nom et prénoms du premier responsable': 'nom_resp',
    'Sexe du premier responsable : ': 'sexe_resp',
    'Adresse complète du premier responsable : ': 'adresse_resp',
    'Niveau instruction du premier responsable  : ': 'niveau_instruction_resp',
    'Numéro de téléphone principal du premier responsable :  ': 'tel_principal_resp',
    'Numéro de téléphone secondaire du premier responsable :  ': 'tel_secondaire_resp',
    'Adresse électronique (mail) du premier responsable : ': 'email_resp',
    'Statut sur le plan foncier du premier responsable : ': 'statut_foncier_resp',
    "Nom de l'organisation de base / structure ": 'nom_org',
    'Type d’organisation / structure': 'type_org',
    'Autres ': 'type_org_autres',
    'Effectif des membres : ': 'effectif_membres',
    'Nombre de femmes : ': 'nb_femmes',
    "Nombre d'hommes : ": 'nb_hommes',
    "Date de création de l'organisation : ": 'date_creation_org',
    "Numéro d'enregistrement / immatriculation : ": 'num_immatriculation',
    'Date d’immatriculation de l’organisation à la base (si elle est immatriculée) : ': 'date_immatriculation_org',
    'Adresse du siège de l’organisation : ': 'adresse_siege_org',
    'Coordonnées GPS du siège ou du premier responsable: ': 'gps_org',
    '_Coordonnées GPS du siège ou du premier responsable: _latitude': 'gps_org_lat',
    '_Coordonnées GPS du siège ou du premier responsable: _longitude': 'gps_org_lon',
    '_Coordonnées GPS du siège ou du premier responsable: _altitude': 'gps_org_alt',
    '_Coordonnées GPS du siège ou du premier responsable: _precision': 'gps_org_prec',
    'Adresse électronique de l’organisation à la base : ': 'email_org',
    'Statut actuel de l’enquêté (organisation à la base) dans la famille : ': 'statut_famille_org',
    'Nom de l’organisation communale / cantonale : ': 'nom_org_communale',
    'Nom de l’organisation préfectorale :': 'nom_org_prefectorale',
    "Nom de l'Union membre de la famille : ": 'nom_union_famille',
    'Volume total moyen annuel de production de plants de mangue (pépinières) pour votre organisation : ': 'vol_prod_plants',
    'Variétés de mangue produites dans votre organisation : ': 'varietes_mangue',
    'Autres': 'varietes_mangue_autres',
    'Variété de mangue dominante dans votre organisation : ': 'variete_mangue_dom',
    'Autres.1': 'variete_mangue_dom_autres',
    'Autres productions que vous effectuez à part les plants de mangue (pépinières) : ': 'autres_prods_pepiniere',

    # --- PROFIL 2 (.1) (ex: Producteurs) ---
    'Nom et prénoms du premier responsable.1': 'nom_resp_prod',
    'Sexe du premier responsable : .1': 'sexe_resp_prod',
    'Adresse complète du premier responsable : .1': 'adresse_resp_prod',
    'Niveau instruction du premier responsable  : .1': 'niveau_instruction_resp_prod',
    'Numéro de téléphone principal du premier responsable :  .1': 'tel_principal_resp_prod',
    'Numéro de téléphone secondaire du premier responsable :  .1': 'tel_secondaire_resp_prod',
    'Adresse électronique (mail) du premier responsable : .1': 'email_resp_prod',
    'Statut sur le plan foncier du premier responsable : .1': 'statut_foncier_resp_prod',
    "Nom de l'organisation de base / structure .1": 'nom_org_prod',
    'Type d’organisation / structure.1': 'type_org_prod',
    'Effectif des membres : .1': 'effectif_membres_prod',
    'Nombre de femmes : .1': 'nb_femmes_prod',
    "Nombre d'hommes : .1": 'nb_hommes_prod',
    "Date de création de l'organisation : .1": 'date_creation_org_prod',
    "Numéro d'enregistrement / immatriculation : .1": 'num_immatriculation_prod',
    'Date d’immatriculation de l’organisation à la base (si elle est immatriculée) : .1': 'date_immatriculation_org_prod',
    'Adresse du siège de l’organisation : .1': 'adresse_siege_org_prod',
    'Coordonnées GPS du siège ou du premier responsable: .1': 'gps_org_prod',
    '_Coordonnées GPS du siège ou du premier responsable: _latitude.1': 'gps_org_prod_lat',
    '_Coordonnées GPS du siège ou du premier responsable: _longitude.1': 'gps_org_prod_lon',
    '_Coordonnées GPS du siège ou du premier responsable: _altitude.1': 'gps_org_prod_alt',
    '_Coordonnées GPS du siège ou du premier responsable: _precision.1': 'gps_org_prod_prec',
    'Adresse électronique de l’organisation à la base : .1': 'email_org_prod',
    'Statut actuel de l’enquêté (organisation à la base) dans la famille : .1': 'statut_famille_org_prod',
    'Nom de l’organisation communale / cantonale : .1': 'nom_org_communale_prod',
    'Nom de l’organisation préfectorale :.1': 'nom_org_prefectorale_prod',
    "Nom de l'Union membre de la famille : .1": 'nom_union_famille_prod',
    'Superficie totale moyenne emblavée annuellement par votre organisation pour la production de mangue : ': 'superficie_mangue_org',
    'Nombre total moyen de plants de manguiers de votre organisation pour la production de mangue  ': 'nb_plants_manguiers',
    'Variétés de mangue produites dans votre organisation : .1': 'varietes_mangue_prod',
    'Autres.2': 'varietes_mangue_prod_autres',
    'Variété de mangue dominante dans votre organisation : .1': 'variete_mangue_dom_prod',
    'Autres.3': 'variete_mangue_dom_prod_autres',
    'Volume total moyen annuel de production de mangue de votre organisation : ': 'vol_prod_mangue',
    'Autres productions que vous effectuez à part la mangue : ': 'autres_prods_mangue',
    'Superficie totale moyenne emblavée annuellement par les membres de votre organisation pour la production de mangue : ': 'superficie_mangue_membres',

    # --- PROFIL 3 (.2, .3, .4) (ex: Entreprises / Transformateurs) ---
    'Nom et prénoms du premier responsable.2': 'nom_resp_ent',
    'Sexe du premier responsable : .2': 'sexe_resp_ent',
    'Adresse complète du premier responsable : .2': 'adresse_resp_ent',
    'Niveau instruction du premier responsable  : .2': 'niveau_instruction_resp_ent',
    'Numéro de téléphone principal du premier responsable :  .2': 'tel_principal_resp_ent',
    'Numéro de téléphone secondaire du premier responsable :  .2': 'tel_secondaire_resp_ent',
    'Adresse électronique (mail) du premier responsable : .2': 'email_resp_ent',
    'Statut sur le plan foncier du premier responsable : .2': 'statut_foncier_resp_ent',
    "Raison sociale de l'entreprise ": 'nom_ent',
    'Statut juridique :': 'statut_juridique_ent',
    'Autres: ': 'statut_juridique_ent_autres',
    "Effectif des membres / personnels de l'entreprise : ": 'effectif_personnel_ent',
    'Nombre de femmes : .2': 'nb_femmes_ent',
    "Nombre d'hommes : .2": 'nb_hommes_ent',
    "Date de création de l'entreprise : ": 'date_creation_ent',
    "Numéro d'enregistrement / immatriculation : .2": 'num_immatriculation_ent',
    'Date d’immatriculation de l’organisation à la base (si elle est immatriculée) : .2': 'date_immatriculation_ent',
    'Adresse du siège de l’entreprise: ': 'adresse_siege_ent',
    'Coordonnées GPS : ': 'gps_ent',
    '_Coordonnées GPS : _latitude': 'gps_ent_lat',
    '_Coordonnées GPS : _longitude': 'gps_ent_lon',
    '_Coordonnées GPS : _altitude': 'gps_ent_alt',
    '_Coordonnées GPS : _precision': 'gps_ent_prec',
    'Adresse électronique de l’entreprise : ': 'email_ent',
    'Statut actuel de l’enquêté (entreprise) dans la famille : ': 'statut_famille_ent',
    "Statut sur le plan foncier (lieu d'installation de l'unité) ": 'statut_foncier_unite',
    'Produits dérivés à base de mangue : ': 'produits_derives',
    'Autres.4': 'produits_derives_autres',
    'Produit dérivé spécifique à base de mangue dominant dans votre activité : ': 'produit_derive_dom',
    'Autres .1': 'produit_derive_dom_autres',
    'Volume moyen annuel de produits achetés  :': 'vol_achats',
    'Volume moyen annuel de produits vendus : ': 'vol_ventes',
    'Type de certification : ': 'type_certif',
    "Nom de l'organisme certificateur : ": 'organisme_certif',
    'Autres produits que vous effectuez à part la mangue: ': 'autres_produits_ent',
    'Produits transformés à base de mangue :': 'produits_transformes',
    "Volume total moyen annuel de mangue transformé par l'entreprise :": 'vol_transforme',
    'Volume moyen annuel de vente de mangue ou dérivés de la mangue de l’entreprise : ': 'vol_ventes_derives',
    'Autres productions que vous effectuez à part la mangue: ': 'autres_prods_ent',

    # --- VARIABLES RÉSIDUELLES (Doublons de téléphone) ---
    'Numéro de téléphone secondaire : .1': 'tel_secondaire_repondant_alt',
    'Numéro de téléphone principal du premier responsable :  .3': 'tel_principal_resp_alt_3',
    'Numéro de téléphone secondaire du premier responsable :  .3': 'tel_secondaire_resp_alt_3',
    'Numéro de téléphone principal du premier responsable :  .4': 'tel_principal_resp_alt_4',
    'Numéro de téléphone secondaire du premier responsable :  .4': 'tel_secondaire_resp_alt_4'
}
   
df = df.rename( columns = renommer_colonnes)
df.head()
# Out:
#   date_enquete         nom_enqueteur   village    canton   region  \
# 0   2026-03-05   Doumougue daminsete    Namouk  Tamongue   Savane
# 1   2026-03-05  Doumougue  daminsete    Namouk  Tamongue  Savanes
# 2   2026-03-09   Doumougue daminsete    Namouk  Tamongue  Savanes
# 3   2026-03-09   Doumougue damonsete    Namoik  Tamongue  Savanes
# 4   2026-03-16   Doumougue daminsete  Nayargue  Tamongue  Savanes
#
#     type_acteur         nom_repondant sexe_repondant  \
# 0  Producteurs              Lare gani          Homme
# 1  Producteurs   Kombate limanguedame          Homme
# 2  Producteurs             Lare noaka          Homme
# 3  Producteurs    Doumougue daminsete          Homme
# 4  Producteurs        Kolani poukinin          Homme
#
#   niveau_instruction_repondant  tel_principal_repondant  ...  \
# 0                        Aucun                 93145658  ...
# 1                        Aucun                 71490229  ...
# ...

# %%
print(df.columns.tolist())
# Out:
# ['date_enquete', 'nom_enqueteur', 'village', 'canton', 'region', 'type_acteur', 'nom_repondant', 'sexe_repondant', 'niveau_instruction_repondant', 'tel_principal_repondant', 'tel_secondaire_repondant', 'email_repondant', 'poste_repondant', 'nom_resp', 'sexe_resp', 'adresse_resp', 'niveau_instruction_resp', 'tel_principal_resp', 'tel_secondaire_resp', 'email_resp', 'statut_foncier_resp', 'nom_org', 'type_org', 'type_org_autres', 'effectif_membres', 'nb_femmes', 'nb_hommes', 'date_creation_org', 'num_immatriculation', 'date_immatriculation_org', 'adresse_siege_org', 'gps_org', 'gps_org_lat', 'gps_org_lon', 'gps_org_alt', 'gps_org_prec', 'email_org', 'statut_famille_org', 'nom_org_communale', 'nom_org_prefectorale', 'nom_union_famille', 'vol_prod_plants', 'varietes_mangue', 'varietes_mangue_autres', 'variete_mangue_dom', 'variete_mangue_dom_autres', 'autres_prods_pepiniere', 'nom_resp_prod', 'sexe_resp_prod', 'adresse_resp_prod', 'niveau_instruction_resp_prod', 'tel_principal_resp_prod'
# ...

# %%
colonnes_a_fusionner_mangue = {
    # --- INFOS RÉPONDANT ---
    'repondant_tel_secondaire_unique': ['tel_secondaire_repondant', 'tel_secondaire_repondant_alt'],

    # --- INFOS RESPONSABLE ---
    'resp_nom_unique': ['nom_resp', 'nom_resp_prod', 'nom_resp_ent'],
    'resp_sexe_unique': ['sexe_resp', 'sexe_resp_prod', 'sexe_resp_ent'],
    'resp_adresse_unique': ['adresse_resp', 'adresse_resp_prod', 'adresse_resp_ent'],
    'resp_niveau_instruction_unique': ['niveau_instruction_resp', 'niveau_instruction_resp_prod', 'niveau_instruction_resp_ent'],
    'resp_tel_principal_unique': ['tel_principal_resp', 'tel_principal_resp_prod', 'tel_principal_resp_ent', 'tel_principal_resp_alt_3', 'tel_principal_resp_alt_4'],
    'resp_tel_secondaire_unique': ['tel_secondaire_resp', 'tel_secondaire_resp_prod', 'tel_secondaire_resp_ent', 'tel_secondaire_resp_alt_3', 'tel_secondaire_resp_alt_4'],
    'resp_email_unique': ['email_resp', 'email_resp_prod', 'email_resp_ent'],
    'resp_statut_foncier_unique': ['statut_foncier_resp', 'statut_foncier_resp_prod', 'statut_foncier_resp_ent'],

    # --- INFOS ENTITÉ ---
    'entite_nom_unique': ['nom_org', 'nom_org_prod', 'nom_ent'],
    'entite_type_unique': ['type_org', 'type_org_prod', 'statut_juridique_ent'],
    'entite_effectif_total_unique': ['effectif_membres', 'effectif_membres_prod', 'effectif_personnel_ent'],
    'entite_nb_femmes_unique': ['nb_femmes', 'nb_femmes_prod', 'nb_femmes_ent'],
    'entite_nb_hommes_unique': ['nb_hommes', 'nb_hommes_prod', 'nb_hommes_ent'],
    'entite_date_creation_unique': ['date_creation_org', 'date_creation_org_prod', 'date_creation_ent'],
    'entite_num_immatriculation_unique': ['num_immatriculation', 'num_immatriculation_prod', 'num_immatriculation_ent'],
    'entite_date_immatriculation_unique': ['date_immatriculation_org', 'date_immatriculation_org_prod', 'date_immatriculation_ent'],
    'entite_adresse_siege_unique': ['adresse_siege_org', 'adresse_siege_org_prod', 'adresse_siege_ent'],
    'entite_email_unique': ['email_org', 'email_org_prod', 'email_ent'],
    'entite_statut_famille_unique': ['statut_famille_org', 'statut_famille_org_prod', 'statut_famille_ent'],

    # --- INFOS GPS ---
    'gps_unique': ['gps_org', 'gps_org_prod', 'gps_ent'],
    'gps_lat_unique': ['gps_org_lat', 'gps_org_prod_lat', 'gps_ent_lat'],
    'gps_lon_unique': ['gps_org_lon', 'gps_org_prod_lon', 'gps_ent_lon'],
    'gps_alt_unique': ['gps_org_alt', 'gps_org_prod_alt', 'gps_ent_alt'],
    'gps_prec_unique': ['gps_org_prec', 'gps_org_prod_prec', 'gps_ent_prec'],

    # --- APPARTENANCE FAÎTIÈRES ---
    'nom_org_communale_unique': ['nom_org_communale', 'nom_org_communale_prod'],
    'nom_org_prefectorale_unique': ['nom_org_prefectorale', 'nom_org_prefectorale_prod'],
    'nom_union_famille_unique': ['nom_union_famille', 'nom_union_famille_prod'],

    # --- VARIABLES MANGUE SPÉCIFIQUES ---
    'varietes_mangue_unique': ['varietes_mangue', 'varietes_mangue_prod'],
    'variete_mangue_dom_unique': ['variete_mangue_dom', 'variete_mangue_dom_prod'],
    'varietes_mangue_autres_unique': ['varietes_mangue_autres', 'varietes_mangue_prod_autres'],
    
    # Fusionner les "Autres variétés dominantes"
    'variete_mangue_dom_autres_unique': ['variete_mangue_dom_autres', 'variete_mangue_dom_prod_autres']
}

def fusionner_col(df, dictionnaire):
    for base_final, liste_colonnes in dictionnaire.items():
        df[base_final] = df[liste_colonnes[0]]
        for liste_actuelle in liste_colonnes[1:]:
            df[base_final] = df[base_final].fillna(df[liste_actuelle])
    return df
df = fusionner_col(df,colonnes_a_fusionner_mangue)
df.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_39244\2786530732.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[base_final] = df[base_final].fillna(df[liste_actuelle])
#   date_enquete         nom_enqueteur   village    canton   region  \
# 0   2026-03-05   Doumougue daminsete    Namouk  Tamongue   Savane
# 1   2026-03-05  Doumougue  daminsete    Namouk  Tamongue  Savanes
# 2   2026-03-09   Doumougue daminsete    Namouk  Tamongue  Savanes
# 3   2026-03-09   Doumougue damonsete    Namoik  Tamongue  Savanes
# 4   2026-03-16   Doumougue daminsete  Nayargue  Tamongue  Savanes
#
#     type_acteur         nom_repondant sexe_repondant  \
# 0  Producteurs              Lare gani          Homme
# 1  Producteurs   Kombate limanguedame          Homme
# ...

# %%
liste_supprimer = []

for ancienne_liste in colonnes_a_fusionner_mangue.values():
    liste_supprimer.extend(ancienne_liste)

# La modification clé est ici : "df = ..."
df = df.drop(columns=liste_supprimer)

df.head()
# Out:
#   date_enquete         nom_enqueteur   village    canton   region  \
# 0   2026-03-05   Doumougue daminsete    Namouk  Tamongue   Savane
# 1   2026-03-05  Doumougue  daminsete    Namouk  Tamongue  Savanes
# 2   2026-03-09   Doumougue daminsete    Namouk  Tamongue  Savanes
# 3   2026-03-09   Doumougue damonsete    Namoik  Tamongue  Savanes
# 4   2026-03-16   Doumougue daminsete  Nayargue  Tamongue  Savanes
#
#     type_acteur         nom_repondant sexe_repondant  \
# 0  Producteurs              Lare gani          Homme
# 1  Producteurs   Kombate limanguedame          Homme
# 2  Producteurs             Lare noaka          Homme
# 3  Producteurs    Doumougue daminsete          Homme
# 4  Producteurs        Kolani poukinin          Homme
#
#   niveau_instruction_repondant  tel_principal_repondant  ... gps_lon_unique  \
# 0                        Aucun                 93145658  ...       0.225650
# 1                        Aucun                 71490229  ...       0.224907
# ...

# %%
print(df['region'].value_counts())
# Out:
# region
# Kara              156
# Plateau Ouest      66
# Centrale           51
# Plateaux           25
# MARITIME           19
# Maritime           10
# Kara                8
# Plateau             7
# Plateau x           6
# Savanes             6
# Plateau x           5
# Plateau             4
# Plateau Ouest       2
# Plateaux            2
# Savane              1
#  Savane             1
# Sotouboua           1
# Akplolo             1
# Name: count, dtype: int64

# %%
df['region']=df['region'].str.strip().str.upper()

nettoyage_regions = {
    # --- KARA ---
    'KARA': 'KARA',
    
    # --- PLATEAUX ---
    'PLATEAU OUEST': 'PLATEAUX',
    'PLATEAUX': 'PLATEAUX',
    'PLATEAU': 'PLATEAUX',
    'PLATEAU X': 'PLATEAUX',
    'AKPLOLO': 'PLATEAUX',
    
    # --- MARITIME ---
    'MARITIME': 'MARITIME',
    
    # --- CENTRALE ---
    'CENTRALE': 'CENTRALE',
    'SOTOUBOUA': 'CENTRALE',
    
    # --- SAVANES ---
    'SAVANES': 'SAVANES',
    'SAVANE': 'SAVANES'
}

df['region'] = df['region'].replace(nettoyage_regions)
print(df['region'].value_counts())
# Out:
# region
# KARA        164
# PLATEAUX    118
# CENTRALE     52
# MARITIME     29
# SAVANES       8
# Name: count, dtype: int64

# %%
# On remplace le texte "_final" par "rien du tout" (une chaîne de caractères vide '')
df.columns = df.columns.str.replace('_unique', '')

# On affiche le résultat pour admirer le travail !
print(df.columns.tolist())
# Out:
# ['date_enquete', 'nom_enqueteur', 'village', 'canton', 'region', 'type_acteur', 'nom_repondant', 'sexe_repondant', 'niveau_instruction_repondant', 'tel_principal_repondant', 'email_repondant', 'poste_repondant', 'type_org_autres', 'vol_prod_plants', 'autres_prods_pepiniere', 'superficie_mangue_org', 'nb_plants_manguiers', 'vol_prod_mangue', 'autres_prods_mangue', 'statut_juridique_ent_autres', 'statut_foncier_unite', 'produits_derives', 'produits_derives_autres', 'produit_derive_dom', 'produit_derive_dom_autres', 'vol_achats', 'vol_ventes', 'type_certif', 'organisme_certif', 'autres_produits_ent', 'superficie_mangue_membres', 'produits_transformes', 'vol_transforme', 'vol_ventes_derives', 'autres_prods_ent', 'repondant_tel_secondaire', 'resp_nom', 'resp_sexe', 'resp_adresse', 'resp_niveau_instruction', 'resp_tel_principal', 'resp_tel_secondaire', 'resp_email', 'resp_statut_foncier', 'entite_nom', 'entite_type', 'entite_effectif_total', 'entite_nb_femmes', 'entite_nb_hommes', 'entite_
# ...

# %%
for col in df.columns:
    print(f'____{col}____')
    print(df[col].value_counts())
    print('\n')
# Out:
# ____date_enquete____
# date_enquete
# 2026-04-21    52
# 2026-04-22    35
# 2026-04-27    27
# 2026-05-13    22
# 2026-05-16    18
# 2026-05-04    18
# 2026-04-24    17
# 2026-04-15    15
# 2026-04-16    12
# 2026-05-12    11
# 2026-04-20    11
# 2026-04-30    10
# 2026-04-25    10
# 2026-05-03     9
# 2026-04-29     9
# 2026-04-13     9
# 2026-05-14     8
# 2026-04-28     8
# 2026-05-06     7
# 2026-04-26     6
# 2026-04-14     6
# 2026-04-23     6
# 2026-05-07     5
# 2026-05-05     5
# 2026-05-15     4
# 2026-04-09     3
# 2026-04-02     3
# 2026-04-17     3
# 2026-04-18     2
# 2026-03-09     2
# 2026-04-04     2
# 2026-04-10     2
# 2026-03-05     2
# 2026-04-05     2
# 2026-03-16     1
# 2026-03-20     1
# 2026-04-11     1
# 2017-11-23     1
# 2026-04-03     1
# 2026-04-08     1
# 2029-02-27     1
# 2026-03-02     1
# 2026-02-10     1
# 2026-02-17     1
# Name: count, dtype: int64
#
#
# ____nom_enqueteur____
# nom_enqueteur
# ABI Essoyomewè               146
# ...

# %%
import pandas as pd

# 1. Uniformisation de base
df['nom_enqueteur'] = df['nom_enqueteur'].astype(str).str.replace('"', '', regex=False)
df['nom_enqueteur'] = df['nom_enqueteur'].str.strip().str.upper()

# 2. Dictionnaire de corrections Regex adapté à cette 4ème liste
corrections_enqueteurs_4 = {
    r'^.*ABI.*$': 'ABI ESSOYOMEWÈ',
    r'^.*DZAH.*$': 'DZAH YAWO AMEDZEAFE',
    r'^.*AKABA.*$': 'AKABA ESSODINA',
    r'^.*ADINDA.*$': 'ADINDA-AKPO A. AFFO',
    r'^.*AMEGAN.*$': 'AMEGAN KOMLA FAFALI',
    r'^.*TOLO.*$': 'TOLO DJAMIOU',
    r'^.*LAWSON.*$': 'LAWSON-TOGLA LATÉ VÉVÉ',
    r'^.*ADEGNON.*$': 'ADEGNON YAO GABRIEL',
    r'^.*ASSOGBA.*$': 'ASSOGBA SALAM',
    r'^.*BODI.*$': 'BODI KAGO MAROUANE',
    r'^.*DOUMOUGUE.*$': 'DOUMOUGUE DAMINSETE',
    r'^.*DANDJA.*$': 'DANDJA NAMTIEBE',
    r'^.*AGBOLETE.*$': 'AGBOLETE KOMLAGAN JEAN',
    r'^.*LARE.*$': 'LARE YENDOUNAME',
    r'^.*ADO.*$': 'ADO HILARY',
    r'^.*MAMAH.*$': 'MAMAH YAKOUBOU'
}

# 3. Application du remplacement
df['nom_enqueteur'] = df['nom_enqueteur'].replace(corrections_enqueteurs_4, regex=True)

# 4. Vérification finale
print(df['nom_enqueteur'].value_counts())
# Out:
# nom_enqueteur
# ABI ESSOYOMEWÈ            157
# DZAH YAWO AMEDZEAFE        68
# ADINDA-AKPO A. AFFO        27
# AKABA ESSODINA             25
# TOLO DJAMIOU               21
# LAWSON-TOGLA LATÉ VÉVÉ     20
# AMEGAN KOMLA FAFALI        19
# ASSOGBA SALAM              10
# ADEGNON YAO GABRIEL         8
# DOUMOUGUE DAMINSETE         5
# BODI KAGO MAROUANE          4
# ADO HILARY                  2
# DANDJA NAMTIEBE             2
# LARE YENDOUNAME             1
# AGBOLETE KOMLAGAN JEAN      1
# MAMAH YAKOUBOU              1
# Name: count, dtype: int64

# %%
df['date_enquete'] = pd.to_datetime(df['date_enquete'],errors = 'coerce')
df['date_enquete'] = df['date_enquete'].dt.date

print(df['date_enquete'].head())
# Out:
# 0    2026-03-05
# 1    2026-03-05
# 2    2026-03-09
# 3    2026-03-09
# 4    2026-03-16
# Name: date_enquete, dtype: object

# %%
# première lettre en majuscule et le reste en minuscule
colonne_a_convertir = ['village', 'canton','resp_adresse','nom_repondant']

# Boucle pour changer la première lettre
for col in colonne_a_convertir:
    df[col] = df[col].astype(str).str.capitalize()

df[colonne_a_convertir]=df[colonne_a_convertir].replace('Nan','')

# %%
# Sauvegarde en Excel
df.to_excel("Mangue_propre4.xlsx", index=False)
